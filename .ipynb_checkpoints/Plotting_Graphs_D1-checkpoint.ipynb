# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt

# %% [markdown]
# # Load and Process Data

# %%
# === Load Features ===
gin_gout_file = "Data_D2/gin_gout_ratio.csv"
df_features = pd.read_csv(gin_gout_file, header=None)
X = df_features.values  # Features: gout/gin ratios

# === Load Labels ===
test_info_file = "Data_D2/test_info.csv"
df_labels = pd.read_csv(test_info_file, header=None)

# %% [markdown]
# # Train Test Split and Transform

# %%
# === Rename columns to match paper notation ===
V_values = df_labels.iloc[:, 0].values  # ✅ V = Capacity (Link Capacity)
C_values = df_labels.iloc[:, 1].values  # ✅ C = Cross Traffic
A_values = V_values - C_values          # ✅ A = Available Bandwidth

# === Debug Print ===
print("Unique Capacity (C) values:", np.unique(C_values))

# === Create Labels Matrix ===
# [A, V] as per the paper (Available Bandwidth, Capacity)
y = np.column_stack((A_values, C_values))  

# === Sanity Check: Match Feature and Label Counts ===
if len(X) != len(y):
    raise ValueError(f"Mismatch: {len(X)} features vs {len(y)} labels.")

# === Normalize A and V using MinMaxScaler ===
scaler = MinMaxScaler()
y_scaled = scaler.fit_transform(y)  # Normalize labels

# === Train/Test Split ===
X_train, X_test, y_train, y_test = train_test_split(
    X, y_scaled, test_size=0.2, random_state=42
)

# === Visualize Input Feature Distribution ===
plt.hist(X.flatten(), bins=50)
plt.title("Distribution of gout/gin ratios")
plt.xlabel("gout/gin")
plt.ylabel("Frequency")
plt.grid(True)
plt.show()
# Out:
# Unique Capacity (C) values: [12.5 25.  37.5]

# %% [markdown]
# # Iterative Model

# %%
def build_iterative_bandwidth_estimator(k=20):
    model = keras.Sequential([
        layers.Input(shape=(k+2,)),  
        layers.Dense(64, activation='relu'),  # Increased neurons
        layers.Dense(32, activation='relu'),  # Added hidden layer
        layers.Dense(2, activation='linear')  # Output: A and C
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %% [markdown]
# # Train the Model

# %%
# Train the model
iterative_model = build_iterative_bandwidth_estimator(X_train.shape[1])
iterative_model.fit(np.hstack([X_train, np.zeros((X_train.shape[0], 2))]), y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2071 - mae: 0.3741 - val_loss: 0.1152 - val_mae: 0.2848
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1089 - mae: 0.2767 - val_loss: 0.0820 - val_mae: 0.2349
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0851 - mae: 0.2359 - val_loss: 0.0683 - val_mae: 0.2089
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0643 - mae: 0.2000 - val_loss: 0.0635 - val_mae: 0.2044
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0533 - mae: 0.1850 - val_loss: 0.0524 - val_mae: 0.1741
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0464 - mae: 0.1649 - val_loss: 0.0477 - val_mae: 0.1639
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0390 - mae: 0.1547 - val_loss: 0.0440 - val_mae: 0.1474
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0401 - mae: 0.1553 - val_loss: 0.0416 - val_mae: 0.1413
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0332 - mae: 0.1346 - val_loss: 0.0373 - val_mae: 0.1363
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0353 - mae: 0.1369 - val_loss: 0.0365 - val_mae: 0.1331
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0304 - mae: 0.1300 - val_loss: 0.0339 - val_mae: 0.1268
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0300 - mae: 0.1260 - val_loss: 0.0323 - val_mae: 0.1239
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0296 - mae: 0.1242 - val_loss: 0.0309 - val_mae: 0.1202
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0267 - mae: 0.1184 - val_loss: 0.0296 - val_mae: 0.1201
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0322 - mae: 0.1205 - val_loss: 0.0331 - val_mae: 0.1240
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0409 - mae: 0.1254 - val_loss: 0.0300 - val_mae: 0.1271
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0320 - mae: 0.1244 - val_loss: 0.0311 - val_mae: 0.1300
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0258 - mae: 0.1190 - val_loss: 0.0301 - val_mae: 0.1221
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0298 - mae: 0.1283 - val_loss: 0.0264 - val_mae: 0.1130
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0216 - mae: 0.1086 - val_loss: 0.0296 - val_mae: 0.1211
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0231 - mae: 0.1122 - val_loss: 0.0244 - val_mae: 0.1091
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0218 - mae: 0.1099 - val_loss: 0.0240 - val_mae: 0.1103
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0206 - mae: 0.1099 - val_loss: 0.0277 - val_mae: 0.1224
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0240 - mae: 0.1151 - val_loss: 0.0226 - val_mae: 0.1047
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0206 - mae: 0.1085 - val_loss: 0.0232 - val_mae: 0.1069
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0193 - mae: 0.1054 - val_loss: 0.0229 - val_mae: 0.1033
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0174 - mae: 0.0975 - val_loss: 0.0230 - val_mae: 0.1033
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0179 - mae: 0.1000 - val_loss: 0.0201 - val_mae: 0.0978
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0169 - mae: 0.0960 - val_loss: 0.0224 - val_mae: 0.1085
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0177 - mae: 0.0996 - val_loss: 0.0213 - val_mae: 0.1004
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0170 - mae: 0.0966 - val_loss: 0.0226 - val_mae: 0.1070
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0182 - mae: 0.0980 - val_loss: 0.0226 - val_mae: 0.1073
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0191 - mae: 0.1055 - val_loss: 0.0193 - val_mae: 0.0957
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165 - mae: 0.0943 - val_loss: 0.0197 - val_mae: 0.0961
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0159 - mae: 0.0930 - val_loss: 0.0182 - val_mae: 0.0928
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0243 - mae: 0.1056 - val_loss: 0.0192 - val_mae: 0.0947
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0178 - mae: 0.0942 - val_loss: 0.0175 - val_mae: 0.0915
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0321 - mae: 0.0946 - val_loss: 0.0179 - val_mae: 0.0900
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0154 - mae: 0.0899 - val_loss: 0.0182 - val_mae: 0.0928
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0206 - mae: 0.0910 - val_loss: 0.0184 - val_mae: 0.0948
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0227 - mae: 0.0935 - val_loss: 0.0202 - val_mae: 0.1042
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0137 - mae: 0.0881 - val_loss: 0.0176 - val_mae: 0.0918
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0123 - mae: 0.0814 - val_loss: 0.0157 - val_mae: 0.0873
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0134 - mae: 0.0854 - val_loss: 0.0189 - val_mae: 0.0944
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0114 - mae: 0.0796 - val_loss: 0.0150 - val_mae: 0.0815
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0104 - mae: 0.0767 - val_loss: 0.0152 - val_mae: 0.0809
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0119 - mae: 0.0827 - val_loss: 0.0164 - val_mae: 0.0893
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0122 - mae: 0.0802 - val_loss: 0.0152 - val_mae: 0.0802
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0099 - mae: 0.0733 - val_loss: 0.0157 - val_mae: 0.0827
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0101 - mae: 0.0755 - val_loss: 0.0146 - val_mae: 0.0780

# %% [markdown]
# # Iterative Prediction

# %%
def iterative_prediction(model, X, num_iterations=5, initial_A=50, initial_C=100):
    """
    Iteratively refines predictions for A (Available Bandwidth) and C (Capacity).
    
    Args:
    - model: Trained iterative NN model.
    - X: Input feature matrix (g_out/g_in ratios).
    - num_iterations: Number of refinement steps.
    - initial_A: Initial guess for Available Bandwidth.
    - initial_C: Initial guess for Capacity.
    
    Returns:
    - A, C estimates after iterations.
    """
    A_pred = np.full((X.shape[0], 1), initial_A)
    C_pred = np.full((X.shape[0], 1), initial_C)
    
    for _ in range(num_iterations):
        input_data = np.hstack([X, A_pred, C_pred])  # Combine features with previous estimates
        predictions = model.predict(input_data)
        A_pred, C_pred = predictions[:, 0].reshape(-1, 1), predictions[:, 1].reshape(-1, 1)
    
    return A_pred, C_pred

# %% [markdown]
# # Print the Results

# %%
# Evaluate model
A_pred, C_pred = iterative_prediction(iterative_model, X_test)
mse_A = np.mean((A_pred - y_test[:, 0])**2)
mse_C = np.mean((C_pred - y_test[:, 1])**2)

print(f'MSE for A: {mse_A:.4f}, MSE for C: {mse_C:.4f}')
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 673us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# MSE for A: 0.7536, MSE for C: 0.5426

# %% [markdown]
# # Simple NN Model

# %%
# Define the model (same as your `build_bandwidth_estimator`)
def build_bandwidth_estimator(k=25):
    model = keras.Sequential([
        layers.Input(shape=(k,)),  # Input layer (expects 20 features)
        layers.Dense(40, activation='relu'),  # Hidden layer with 40 neurons
        layers.Dense(2, activation='linear')  # Output layer (predicts A and C)
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Ensure input dimension matches model expectation
k = X_train.shape[1]
model = build_bandwidth_estimator(k)
model.summary()

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                      │ (None, 40)                  │             880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 2)                   │              82 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 962 (3.76 KB)
#  Trainable params: 962 (3.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4882 - mae: 0.4570 - val_loss: 0.1609 - val_mae: 0.3345
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1774 - mae: 0.3401 - val_loss: 0.1342 - val_mae: 0.3073
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1443 - mae: 0.3197 - val_loss: 0.1159 - val_mae: 0.2842
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1349 - mae: 0.2851 - val_loss: 0.1004 - val_mae: 0.2628
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0941 - mae: 0.2563 - val_loss: 0.0923 - val_mae: 0.2510
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0836 - mae: 0.2395 - val_loss: 0.0954 - val_mae: 0.2576
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0808 - mae: 0.2334 - val_loss: 0.0802 - val_mae: 0.2265
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0707 - mae: 0.2209 - val_loss: 0.0736 - val_mae: 0.2072
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0613 - mae: 0.2034 - val_loss: 0.0724 - val_mae: 0.2027
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0582 - mae: 0.1906 - val_loss: 0.0692 - val_mae: 0.1844
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0486 - mae: 0.1751 - val_loss: 0.0759 - val_mae: 0.2095
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0525 - mae: 0.1800 - val_loss: 0.0677 - val_mae: 0.1848
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0549 - mae: 0.1817 - val_loss: 0.0655 - val_mae: 0.1764
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0471 - mae: 0.1720 - val_loss: 0.0682 - val_mae: 0.1852
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0546 - mae: 0.1681 - val_loss: 0.0673 - val_mae: 0.1841
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0513 - mae: 0.1721 - val_loss: 0.0620 - val_mae: 0.1670
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0436 - mae: 0.1616 - val_loss: 0.0609 - val_mae: 0.1600
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0438 - mae: 0.1614 - val_loss: 0.0602 - val_mae: 0.1637
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0479 - mae: 0.1611 - val_loss: 0.0588 - val_mae: 0.1595
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0390 - mae: 0.1503 - val_loss: 0.0572 - val_mae: 0.1566
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0430 - mae: 0.1551 - val_loss: 0.0564 - val_mae: 0.1559
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0493 - mae: 0.1601 - val_loss: 0.0556 - val_mae: 0.1551
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0449 - mae: 0.1501 - val_loss: 0.0549 - val_mae: 0.1507
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0463 - mae: 0.1561 - val_loss: 0.0545 - val_mae: 0.1588
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0458 - mae: 0.1579 - val_loss: 0.0515 - val_mae: 0.1493
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0372 - mae: 0.1448 - val_loss: 0.0511 - val_mae: 0.1492
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0384 - mae: 0.1450 - val_loss: 0.0553 - val_mae: 0.1664
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.
iter_preds_actual = scaler.inverse_transform(np.hstack([A_pred, C_pred]))

# === Extract values ===
A_true = y_test_actual[:, 0]            # Available Bandwidth
C_true = y_test_actual[:, 1]            # Cross Traffic (C)

A_simple = simple_preds_actual[:, 0]
C_simple = simple_preds_actual[:, 1]

A_iterative = iter_preds_actual[:, 0]
C_iterative = iter_preds_actual[:, 1]

# === Comparison DataFrame ===
df_C_comparison = pd.DataFrame({
    "True C (Cross Traffic)": C_true,
    "Predicted C (Simple NN)": C_simple,
    "Predicted C (Iterative NN)": C_iterative
})

# === Show Comparison ===
print(df_C_comparison.head(20))
print("\nUnique Cross Traffic values in this batch:", np.unique(C_true))
# Out:
#     True C (Cross Traffic)  Predicted C (Simple NN)  \
# 0                     37.5                36.879791
# 1                     37.5                36.815063
# 2                     25.0                24.306732
# 3                     37.5                38.364391
# 4                     37.5                37.168488
# 5                     12.5                17.478132
# 6                     25.0                23.340605
# 7                     37.5                36.344532
# 8                     25.0                24.879740
# 9                     25.0                22.079069
# 10                    37.5                38.485905
# 11                    12.5                20.184855
# 12                    25.0                16.001402
# 13                    25.0                22.427439
# 14                    37.5                36.441975
# 15                    37.5                30.227121
# 16                    12.5                 7.357883
# 17                    37.5                35.199158
# 18                    25.0                22.262804
# 19                    25.0                25.765266
#
#     Predicted C (Iterative NN)
# 0                    29.521847
# 1                    28.968426
# 2                    15.534321
# 3                    28.952915
# 4                    26.716890
# 5                     5.436140
# 6                    15.631650
# 7                    25.466707
# 8                    18.682756
# 9                     8.885269
# 10                   23.710133
# 11                    9.340900
# 12                   15.114999
# 13                   13.253963
# 14                   27.853588
# 15                   27.390205
# 16                   -1.912579
# 17                   22.865311
# 18                   10.236285
# 19                   11.169347
#
# Unique Cross Traffic values in this batch: [12.5 25.  37.5]

# %%
def plot_grouped_C_predictions(true_C, pred_C_dict, bin_width=12.5):
    bins = np.arange(0, np.ceil(true_C.max()) + bin_width, bin_width)
    bin_centers = bins[:-1] + bin_width / 2

    plt.figure(figsize=(8, 5))

    for label, pred_C in pred_C_dict.items():
        means, stds = [], []
        for i in range(len(bins) - 1):
            # Include right edge for the last bin to avoid excluding max value
            if i == len(bins) - 2:
                mask = (true_C >= bins[i]) & (true_C <= bins[i + 1])
            else:
                mask = (true_C >= bins[i]) & (true_C < bins[i + 1])

            if np.any(mask):
                means.append(np.mean(pred_C[mask]))
                stds.append(np.std(pred_C[mask]))
            else:
                means.append(np.nan)
                stds.append(np.nan)

        plt.errorbar(bin_centers, means, yerr=stds, fmt='o-', capsize=5, label=label)

    # Add ideal y = x line
    max_val = max(np.ceil(true_C.max()), np.ceil(max([np.nanmax(p) for p in pred_C_dict.values()])))
    plt.plot([0, max_val], [0, max_val], 'k--', label='Ideal (y = x)')

    plt.xlabel("True Cross Traffic (C) [Mbps]")
    plt.ylabel("Predicted Cross Traffic [Mbps]")
    plt.title("Grouped Cross Traffic Predictions with Error Bars")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.xlim(0, max_val)
    plt.ylim(-5, max_val)
    plt.show()

# %%
plot_grouped_C_predictions(
    C_true,
    {
        "Simple NN": C_simple,
        "Iterative NN": C_iterative
    },
    bin_width=12.5
)
