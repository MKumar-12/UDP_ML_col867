# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %% [markdown]
# # Load and Process Data

# %%
# Load gin/gout ratio dataset (features)
gin_gout_df = pd.read_csv('Data_D2//gin_gout_ratio.csv', header=None)
X = gin_gout_df.values  # Convert to NumPy array

# Load A, C values from test_info.csv (labels)
test_info_df = pd.read_csv('Data_D2//test_info.csv', header=None)
y = test_info_df.values  # A (Available Bandwidth) & C (Capacity)

# %% [markdown]
# # Train Test Split and Transform

# %%
gin_gout_file = "Data_D1/gin_gout_ratio.csv"  
df_features = pd.read_csv(gin_gout_file)


test_info_file = "Data_D1/test_info.csv"  
df_labels = pd.read_csv(test_info_file)

# Extract Capacity (C) and Cross Traffic
C_values = df_labels.iloc[:, 0].values  # First column = Capacity (C)
cross_traffic_values = df_labels.iloc[:, 1].values  # Second column = Cross Traffic

# Compute Available Bandwidth (A = C - Cross Traffic)
A_values = C_values - cross_traffic_values

# Combine A and C as labels
y = np.column_stack((A_values, C_values))  # Shape: (num_samples, 2)

# Convert gin/gout ratio DataFrame to NumPy array
X = df_features.values  # Shape: (num_samples, num_features)

# Check dataset alignment
if len(X) != len(y):
    raise ValueError(f"Mismatch: gin_gout_ratio.csv has {len(X)} rows, test_info.csv has {len(y)} labels.")

# Normalize A and C values using MinMaxScaler
scaler = MinMaxScaler()
y_scaled = scaler.fit_transform(y)  # Scale (A, C) values between 0 and 1

# Split into training (80%) and testing (20%) sets
X_train, X_test, y_train, y_test = train_test_split(X, y_scaled, test_size=0.2, random_state=42)

# Plot data distribution to check if gin/gout ratios have useful variations
plt.hist(X.flatten(), bins=50)
plt.title("Distribution of gout/gin ratios")
plt.show()

# %% [markdown]
# # Iterative Model

# %%
def build_iterative_bandwidth_estimator(k=20):
    model = keras.Sequential([
        layers.Input(shape=(k+2,)),  
        layers.Dense(64, activation='relu'),  # Increased neurons
        layers.Dense(32, activation='relu'),  # Added hidden layer
        layers.Dense(2, activation='linear')  # Output: A and C
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# %% [markdown]
# # Train the Model

# %%
# Train the model
iterative_model = build_iterative_bandwidth_estimator(X_train.shape[1])
iterative_model.fit(np.hstack([X_train, np.zeros((X_train.shape[0], 2))]), y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.1226 - mae: 0.2531 - val_loss: 0.0796 - val_mae: 0.1909
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0783 - mae: 0.1959 - val_loss: 0.0706 - val_mae: 0.1768
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0657 - mae: 0.1789 - val_loss: 0.0622 - val_mae: 0.1659
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0603 - mae: 0.1680 - val_loss: 0.0553 - val_mae: 0.1517
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0537 - mae: 0.1547 - val_loss: 0.0490 - val_mae: 0.1479
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0486 - mae: 0.1498 - val_loss: 0.0434 - val_mae: 0.1356
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0400 - mae: 0.1300 - val_loss: 0.0392 - val_mae: 0.1244
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0350 - mae: 0.1190 - val_loss: 0.0395 - val_mae: 0.1277
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0331 - mae: 0.1155 - val_loss: 0.0324 - val_mae: 0.1109
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0309 - mae: 0.1093 - val_loss: 0.0299 - val_mae: 0.0996
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0262 - mae: 0.0995 - val_loss: 0.0289 - val_mae: 0.1024
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0225 - mae: 0.0893 - val_loss: 0.0250 - val_mae: 0.0903
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0225 - mae: 0.0905 - val_loss: 0.0231 - val_mae: 0.0854
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0205 - mae: 0.0856 - val_loss: 0.0215 - val_mae: 0.0809
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0216 - mae: 0.0873 - val_loss: 0.0202 - val_mae: 0.0772
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0181 - mae: 0.0787 - val_loss: 0.0195 - val_mae: 0.0764
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0165 - mae: 0.0771 - val_loss: 0.0201 - val_mae: 0.0774
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0142 - mae: 0.0716 - val_loss: 0.0184 - val_mae: 0.0741
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0127 - mae: 0.0667 - val_loss: 0.0188 - val_mae: 0.0747
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0138 - mae: 0.0689 - val_loss: 0.0163 - val_mae: 0.0675
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0106 - mae: 0.0601 - val_loss: 0.0177 - val_mae: 0.0691
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0110 - mae: 0.0592 - val_loss: 0.0184 - val_mae: 0.0722
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0125 - mae: 0.0643 - val_loss: 0.0146 - val_mae: 0.0645
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0125 - mae: 0.0600 - val_loss: 0.0143 - val_mae: 0.0606
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0103 - mae: 0.0567 - val_loss: 0.0130 - val_mae: 0.0571
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091 - mae: 0.0525 - val_loss: 0.0175 - val_mae: 0.0624
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0098 - mae: 0.0567 - val_loss: 0.0134 - val_mae: 0.0581
# Epoch 28/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0082 - mae: 0.0515 - val_loss: 0.0125 - val_mae: 0.0540
# Epoch 29/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0090 - mae: 0.0522 - val_loss: 0.0116 - val_mae: 0.0524
# Epoch 30/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0083 - mae: 0.0517 - val_loss: 0.0158 - val_mae: 0.0597
# Epoch 31/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - mae: 0.0534 - val_loss: 0.0113 - val_mae: 0.0522
# Epoch 32/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091 - mae: 0.0528 - val_loss: 0.0117 - val_mae: 0.0507
# Epoch 33/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - mae: 0.0484 - val_loss: 0.0110 - val_mae: 0.0510
# Epoch 34/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0074 - mae: 0.0485 - val_loss: 0.0122 - val_mae: 0.0607
# Epoch 35/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0086 - mae: 0.0512 - val_loss: 0.0121 - val_mae: 0.0485
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0073 - mae: 0.0482 - val_loss: 0.0100 - val_mae: 0.0491
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0072 - mae: 0.0475 - val_loss: 0.0121 - val_mae: 0.0526
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0091 - mae: 0.0514 - val_loss: 0.0127 - val_mae: 0.0536
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0071 - mae: 0.0461 - val_loss: 0.0110 - val_mae: 0.0554
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0068 - mae: 0.0443 - val_loss: 0.0101 - val_mae: 0.0482
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - mae: 0.0438 - val_loss: 0.0103 - val_mae: 0.0504
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0102 - mae: 0.0524 - val_loss: 0.0083 - val_mae: 0.0428
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0065 - mae: 0.0442 - val_loss: 0.0093 - val_mae: 0.0456
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0051 - mae: 0.0391 - val_loss: 0.0096 - val_mae: 0.0434
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0057 - mae: 0.0412 - val_loss: 0.0095 - val_mae: 0.0489
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0066 - mae: 0.0429 - val_loss: 0.0112 - val_mae: 0.0578
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0065 - mae: 0.0423 - val_loss: 0.0111 - val_mae: 0.0549
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0067 - mae: 0.0447 - val_loss: 0.0083 - val_mae: 0.0426
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0057 - mae: 0.0404 - val_loss: 0.0094 - val_mae: 0.0430
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0053 - mae: 0.0386 - val_loss: 0.0073 - val_mae: 0.0414

# %% [markdown]
# # Iterative Prediction

# %%
def iterative_prediction(model, X, num_iterations=5, initial_A=50, initial_C=100):
    """
    Iteratively refines predictions for A (Available Bandwidth) and C (Capacity).
    
    Args:
    - model: Trained iterative NN model.
    - X: Input feature matrix (g_out/g_in ratios).
    - num_iterations: Number of refinement steps.
    - initial_A: Initial guess for Available Bandwidth.
    - initial_C: Initial guess for Capacity.
    
    Returns:
    - A, C estimates after iterations.
    """
    A_pred = np.full((X.shape[0], 1), initial_A)
    C_pred = np.full((X.shape[0], 1), initial_C)
    
    for _ in range(num_iterations):
        input_data = np.hstack([X, A_pred, C_pred])  # Combine features with previous estimates
        predictions = model.predict(input_data)
        A_pred, C_pred = predictions[:, 0].reshape(-1, 1), predictions[:, 1].reshape(-1, 1)
    
    return A_pred, C_pred

# %% [markdown]
# # Print the Results

# %%
# Evaluate model
A_pred, C_pred = iterative_prediction(iterative_model, X_test)
mse_A = np.mean((A_pred - y_test[:, 0])**2)
mse_C = np.mean((C_pred - y_test[:, 1])**2)

print(f'MSE for A: {mse_A:.4f}, MSE for C: {mse_C:.4f}')
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 583us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 635us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 654us/step
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# MSE for A: 0.2889, MSE for C: 0.0003

# %% [markdown]
# # Simple NN Model

# %%
# Define the model (same as your `build_bandwidth_estimator`)
def build_bandwidth_estimator(k=25):
    model = keras.Sequential([
        layers.Input(shape=(k,)),  # Input layer (expects 20 features)
        layers.Dense(40, activation='relu'),  # Hidden layer with 40 neurons
        layers.Dense(2, activation='linear')  # Output layer (predicts A and C)
    ])
    
    model.compile(optimizer='adam', loss='mse', metrics=['mae'])
    return model

# Ensure input dimension matches model expectation
k = X_train.shape[1]
model = build_bandwidth_estimator(k)
model.summary()

# Train the model
model.fit(X_train, y_train, epochs=50, batch_size=32, validation_split=0.2)
# Out:
# Model: "sequential_5"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_13 (Dense)                     │ (None, 40)                  │             880 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_14 (Dense)                     │ (None, 2)                   │              82 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 962 (3.76 KB)
#  Trainable params: 962 (3.76 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3382 - mae: 0.4082 - val_loss: 0.1324 - val_mae: 0.2586
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1333 - mae: 0.2600 - val_loss: 0.1103 - val_mae: 0.2357
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.1084 - mae: 0.2337 - val_loss: 0.0964 - val_mae: 0.2171
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0882 - mae: 0.2074 - val_loss: 0.0843 - val_mae: 0.2033
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0794 - mae: 0.1972 - val_loss: 0.0664 - val_mae: 0.1801
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0623 - mae: 0.1759 - val_loss: 0.0649 - val_mae: 0.1783
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0645 - mae: 0.1754 - val_loss: 0.0577 - val_mae: 0.1671
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0533 - mae: 0.1591 - val_loss: 0.0566 - val_mae: 0.1614
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0503 - mae: 0.1512 - val_loss: 0.0512 - val_mae: 0.1495
# Epoch 10/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0464 - mae: 0.1444 - val_loss: 0.0487 - val_mae: 0.1440
# Epoch 11/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0466 - mae: 0.1428 - val_loss: 0.0460 - val_mae: 0.1359
# Epoch 12/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0425 - mae: 0.1347 - val_loss: 0.0443 - val_mae: 0.1316
# Epoch 13/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0420 - mae: 0.1315 - val_loss: 0.0457 - val_mae: 0.1273
# Epoch 14/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0422 - mae: 0.1329 - val_loss: 0.0417 - val_mae: 0.1225
# Epoch 15/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0378 - mae: 0.1214 - val_loss: 0.0436 - val_mae: 0.1314
# Epoch 16/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0360 - mae: 0.1215 - val_loss: 0.0392 - val_mae: 0.1170
# Epoch 17/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0337 - mae: 0.1153 - val_loss: 0.0386 - val_mae: 0.1143
# Epoch 18/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0401 - mae: 0.1264 - val_loss: 0.0366 - val_mae: 0.1118
# Epoch 19/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0359 - mae: 0.1186 - val_loss: 0.0368 - val_mae: 0.1144
# Epoch 20/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0332 - mae: 0.1134 - val_loss: 0.0350 - val_mae: 0.1080
# Epoch 21/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0325 - mae: 0.1089 - val_loss: 0.0341 - val_mae: 0.1055
# Epoch 22/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0335 - mae: 0.1100 - val_loss: 0.0349 - val_mae: 0.1077
# Epoch 23/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0307 - mae: 0.1053 - val_loss: 0.0353 - val_mae: 0.1079
# Epoch 24/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.0294 - mae: 0.1041 - val_loss: 0.0390 - val_mae: 0.1175
# Epoch 25/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0302 - mae: 0.1062 - val_loss: 0.0316 - val_mae: 0.0983
# Epoch 26/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - loss: 0.0291 - mae: 0.1055 - val_loss: 0.0317 - val_mae: 0.1001
# Epoch 27/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.
#  [ 8.38648617e-01 -4.30398360e-02]
#  [-4.93010730e-02  2.44134571e-04]
#  [ 3.73188198e-01  4.52076783e-03]
#  [ 7.34336734e-01  1.64329400e-03]
#  [ 6.87820196e-01  3.31530860e-03]
#  [ 6.73193455e-01 -5.32777049e-05]
#  [ 6.19067907e-01 -1.18764993e-02]]

# %%
# ==== Inverse-transform predicted values ====
y_test_actual = scaler.inverse_transform(y_test)                      # [A_true, C_true]
simple_preds_actual = scaler.inverse_transform(predictions)          # [A_simple, C_simple]
iter_preds_actual = scaler.inverse_transform(np.hstack([A_pred, C_pred]))  # [A_iterative, C_iterative]

# ==== Extract C (aka V) from true and predicted values ==== 
V_true = y_test_actual[:, 1]
V_simple = simple_preds_actual[:, 1]
V_iterative = iter_preds_actual[:, 1]

# ==== Define plot function for V ==== 
def plot_grouped_predictions_V(true_V, pred_V_dict, title="Grouped V Estimations", bin_width=25):
    bins = np.arange(0, 101, bin_width)
    bin_centers = bins[:-1] + bin_width / 2

    plt.figure(figsize=(7, 5))

    for label, V_pred in pred_V_dict.items():
        means, stds = [], []
        for i in range(len(bins) - 1):
            mask = (true_V >= bins[i]) & (true_V < bins[i + 1])
            if np.sum(mask) > 0:
                means.append(np.mean(V_pred[mask]))
                stds.append(np.std(V_pred[mask]))
            else:
                means.append(np.nan)
                stds.append(np.nan)

        plt.errorbar(bin_centers, means, yerr=stds, fmt='o-', label=label, capsize=5)

    plt.xlabel("True Capacity (Mbps)")
    plt.ylabel("Predicted Capacity (Mbps)")
    plt.title(title)
    plt.grid(True)
    plt.legend()
    plt.xlim(0, 100)
    plt.ylim(0, 120)
    plt.tight_layout()
    plt.show()

# ==== Plot both models for V ==== 
plot_grouped_predictions_V(
    V_true,
    {
        "Simple NN": V_simple,
        "Iterative NN": V_iterative
    },
    title="Predicted V vs True V (Grouped with Error Bars)"
)

# %%
import pandas as pd

# Create a DataFrame for inspection
df_V_comparison = pd.DataFrame({
    "True V (C)": V_true,
    "Predicted V (Simple NN)": V_simple,
    "Predicted V (Iterative NN)": V_iterative
})

# Print the full table or just head
print(df_V_comparison.head(20))  # You can change the number as needed

# Optionally: See the unique values in the ground truth
print("\nUnique true capacity values:", np.unique(V_true))
# Out:
#     True V (C)  Predicted V (Simple NN)  Predicted V (Iterative NN)
# 0        100.0               100.006210                   99.998383
# 1        100.0               100.007202                  100.003937
# 2        100.0               100.002991                  100.002991
# 3        100.0               100.016678                   99.999001
# 4        100.0                99.991096                  100.005699
# 5        100.0                99.994370                  100.025032
# 6        100.0               100.004532                  100.008720
# 7        100.0                99.986572                   99.981430
# 8        100.0                99.994507                  100.018181
# 9        100.0                99.989342                   99.992966
# 10       100.0                99.964134                   99.922577
# 11       100.0               100.001945                  100.029381
# 12       100.0               100.002098                  100.019508
# 13       100.0               100.010780                  100.022163
# 14       100.0               100.034790                   99.981667
# 15       100.0                99.987434                   99.994446
# 16       100.0               100.019890                  100.014999
# 17       100.0               100.013420                  100.005898
# 18       100.0                99.990211                  100.003304
# 19       100.0               100.001381                  100.028610
#
# Unique true capacity values: [100.]
